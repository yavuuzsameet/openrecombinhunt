# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/home/topcuoglu/openrecombinhunt/src/analyse'

# %%
virus = "monkeypox"
metadata_path = f"../../data/raw/{virus}/raw_metadata.tsv" 
df = pd.read_csv(metadata_path, sep="\t")
df.head()
# Out:
#     Accession  BioProjects BioSample accession Completeness  Gene count  \
# 0  OQ565469.1  PRJNA949682                 NaN      PARTIAL       179.0
# 1  OQ565470.1  PRJNA949682                 NaN      PARTIAL       179.0
# 2  OQ565471.1  PRJNA949682                 NaN      PARTIAL       179.0
# 3  OQ565472.1  PRJNA949682                 NaN      PARTIAL       178.0
# 4  OQ565473.1  PRJNA949682                 NaN      PARTIAL       179.0
#
#       Geographic Location Geographic Region Geographic State  \
# 0  USA: NY, New York City     North America               NY
# 1  USA: NY, New York City     North America               NY
# 2  USA: NY, New York City     North America               NY
# 3  USA: NY, New York City     North America               NY
# 4  USA: NY, New York City     North America               NY
#
#    Host Common Name  Host Infraspecific Names Breed  ...  Virus Common Name  \
# 0               NaN                             NaN  ...                NaN
# 1               NaN                             NaN  ...                NaN
# 2               NaN                             NaN  ...                NaN
# 3               NaN                             NaN  ...                NaN
# 4               NaN                             NaN  ...                NaN
#
#    Virus Infraspecific Names Breed  Virus Infraspecific Names Cultivar  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
#
#    Virus Infraspecific Names Ecotype  Virus Infraspecific Names Isolate  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#   Virus Infraspecific Names Sex  Virus Infraspecific Names Strain  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#         Virus Name Virus Pangolin Classification  Virus Taxonomic ID
# 0  Monkeypox virus                           B.1               10244
# 1  Monkeypox virus                           B.1               10244
# 2  Monkeypox virus                           B.1               10244
# 3  Monkeypox virus                           B.1               10244
# 4  Monkeypox virus                           B.1               10244
#
# [5 rows x 50 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of         Accession  BioProjects BioSample accession Completeness  Gene count  \
# 0      OQ565469.1  PRJNA949682                 NaN      PARTIAL       179.0
# 1      OQ565470.1  PRJNA949682                 NaN      PARTIAL       179.0
# 2      OQ565471.1  PRJNA949682                 NaN      PARTIAL       179.0
# 3      OQ565472.1  PRJNA949682                 NaN      PARTIAL       178.0
# 4      OQ565473.1  PRJNA949682                 NaN      PARTIAL       179.0
# ...           ...          ...                 ...          ...         ...
# 10517  OK573171.1  PRJNA231221        SAMN11077999      PARTIAL         NaN
# 10518  OK573172.1  PRJNA231221        SAMN11077999      PARTIAL         NaN
# 10519  OK573173.1  PRJNA231221        SAMN11077999      PARTIAL         NaN
# 10520  OK573174.1  PRJNA231221        SAMN11077999      PARTIAL         NaN
# 10521  OK573175.1  PRJNA231221        SAMN11077999      PARTIAL         NaN
#
#           Geographic Location Geographic Region Geographic State  \
# 0      USA: NY, New York City     North America               NY
# 1      USA: NY, New York City     North America               NY
# 2      USA: NY, New York City     North America               NY
# 3      USA: NY, New York City     North America               NY
# 4      USA: NY, New York City     North America               NY
# ...                       ...               ...              ...
# 10517                 USA: MD     North America               MD
# 10518                 USA: MD     North America               MD
# 10519                 USA: MD     North America               MD
# 10520                 USA: MD     North America               MD
# 10521                 USA: MD     North America               MD
#
#        Host Common Name  Host Infraspecific Names Breed  ...  \
# 0                   NaN                             NaN  ...
# 1                   NaN                             NaN  ...
# 2                   NaN                             NaN  ...
# 3                   NaN                             NaN  ...
# 4                   NaN                             NaN  ...
# ...                 ...                             ...  ...
# 10517               NaN                             NaN  ...
# 10518               NaN                             NaN  ...
# 10519               NaN                             NaN  ...
# 10520               NaN                             NaN  ...
# 10521               NaN                             NaN  ...
#
#        Virus Common Name  Virus Infraspecific Names Breed  \
# 0                    NaN                              NaN
# 1                    NaN                              NaN
# 2                    NaN                              NaN
# 3                    NaN                              NaN
# 4                    NaN                              NaN
# ...                  ...                              ...
# 10517                NaN                              NaN
# 10518                NaN                              NaN
# 10519                NaN                              NaN
# 10520                NaN                              NaN
# 10521                NaN                              NaN
#
#        Virus Infraspecific Names Cultivar  Virus Infraspecific Names Ecotype  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 10517                                 NaN                                NaN
# 10518                                 NaN                                NaN
# 10519                                 NaN                                NaN
# 10520                                 NaN                                NaN
# 10521                                 NaN                                NaN
#
#        Virus Infraspecific Names Isolate Virus Infraspecific Names Sex  \
# 0                                    NaN                           NaN
# 1                                    NaN                           NaN
# 2                                    NaN                           NaN
# 3                                    NaN                           NaN
# 4                                    NaN                           NaN
# ...                                  ...                           ...
# 10517                                NaN                           NaN
# 10518                                NaN                           NaN
# 10519                                NaN                           NaN
# 10520                                NaN                           NaN
# 10521                                NaN                           NaN
#
#        Virus Infraspecific Names Strain       Virus Name  \
# 0                                   NaN  Monkeypox virus
# 1                                   NaN  Monkeypox virus
# 2                                   NaN  Monkeypox virus
# 3                                   NaN  Monkeypox virus
# 4                                   NaN  Monkeypox virus
# ...                                 ...              ...
# 10517                               NaN  Monkeypox virus
# 10518                               NaN  Monkeypox virus
# 10519                               NaN  Monkeypox virus
# 10520                               NaN  Monkeypox virus
# 10521                               NaN  Monkeypox virus
#
#       Virus Pangolin Classification  Virus Taxonomic ID
# 0                               B.1               10244
# 1                               B.1               10244
# 2                               B.1               10244
# 3                               B.1               10244
# 4                               B.1               10244
# ...                             ...                 ...
# 10517                           NaN               10244
# 10518                             A               10244
# 10519                           NaN               10244
# 10520                           NaN               10244
# 10521                           NaN               10244
#
# [10522 rows x 50 columns]>

# %%
df.columns
# Out:
# Index(['Accession', 'BioProjects', 'BioSample accession', 'Completeness',
#        'Gene count', 'Geographic Location', 'Geographic Region',
#        'Geographic State', 'Host Common Name',
#        'Host Infraspecific Names Breed', 'Host Infraspecific Names Cultivar',
#        'Host Infraspecific Names Ecotype', 'Host Infraspecific Names Isolate',
#        'Host Infraspecific Names Sex', 'Host Infraspecific Names Strain',
#        'Host Name', 'Host Pangolin Classification', 'Host Taxonomic ID',
#        'Is Annotated', 'Is Complete', 'Is Lab Host', 'Is Vaccine Strain',
#        'Isolate Collection date', 'Isolate Lineage', 'Isolate Lineage source',
#        'Lab Host', 'Length', 'Mature peptide count', 'Molecule type',
#        'Nucleotide completeness', 'Protein count', 'Purpose of Sampling',
#        'Release date', 'Segment', 'Source database', 'SRA Accessions',
#        'Submitter Affiliation', 'Submitter Country', 'Submitter Names',
#        'Update date', 'Virus Common Name', 'Virus Infraspecific Names Breed',
#        'Virus Infraspecific Names Cultivar',
#        'Virus Infraspecific Names Ecotype',
#        'Virus Infraspecific Names Isolate', 'Virus Infraspecific Names Sex',
#        'Virus Infraspecific Names Strain', 'Virus Name',
#        'Virus Pangolin Classification', 'Virus Taxonomic ID'],
#       dtype='object')

# %%
# display Completeness column
df['Completeness']
# Out:
# 0        PARTIAL
# 1        PARTIAL
# 2        PARTIAL
# 3        PARTIAL
# 4        PARTIAL
#           ...
# 10517    PARTIAL
# 10518    PARTIAL
# 10519    PARTIAL
# 10520    PARTIAL
# 10521    PARTIAL
# Name: Completeness, Length: 10522, dtype: object

# %%
# count NA in 'Completeness' column
na_count = df['Completeness'].isna().sum()

# count PARTIAL values in 'Completeness' column
partial_count = df['Completeness'].value_counts().get('PARTIAL', 0)

# count COMPLETE values in 'Completeness' column
complete_count = df['Completeness'].value_counts().get('COMPLETE', 0)

print(f"NA count: {na_count}")
print(f"PARTIAL count: {partial_count}")
print(f"COMPLETE count: {complete_count}")
# Out:
# NA count: 0
# PARTIAL count: 7021
# COMPLETE count: 3501

# %%
# display Gene count column
df['Gene count']
# Out:
# 0        179.0
# 1        179.0
# 2        179.0
# 3        178.0
# 4        179.0
#          ...
# 10517      NaN
# 10518      NaN
# 10519      NaN
# 10520      NaN
# 10521      NaN
# Name: Gene count, Length: 10522, dtype: float64

# %%
# count NA in 'Gene count' column
na_gene_count = df['Gene count'].isna().sum()

# count of each unique value in 'Gene count' column
gene_count_values = df['Gene count'].value_counts()

print(f"NA in 'Gene count': {na_gene_count}")
print("Unique values in 'Gene count':")
print(gene_count_values)
# Out:
# NA in 'Gene count': 1561
# Unique values in 'Gene count':
# Gene count
# 179.0    4930
# 178.0    1365
# 175.0     973
# 177.0     413
# 1.0       235
#          ...
# 209.0       1
# 20.0        1
# 184.0       1
# 99.0        1
# 75.0        1
# Name: count, Length: 87, dtype: int64

# %%
# display Is Complete column
df['Is Complete']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10517   NaN
# 10518   NaN
# 10519   NaN
# 10520   NaN
# 10521   NaN
# Name: Is Complete, Length: 10522, dtype: float64

# %%
# count NA in Is Complete column
na_count_is_complete = df['Is Complete'].isna().sum()

# count True values in Is Complete column
true_count = df['Is Complete'].value_counts().get(True, 0)

# count False values in Is Complete column
false_count = df['Is Complete'].value_counts().get(False, 0)

print(f"NA count in 'Is Complete': {na_count_is_complete}")
print(f"True count in 'Is Complete': {true_count}")
print(f"False count in 'Is Complete': {false_count}")
# Out:
# NA count in 'Is Complete': 10522
# True count in 'Is Complete': 0
# False count in 'Is Complete': 0

# %%
# display Length column
df['Length']
# Out:
# 0        195656
# 1        195656
# 2        195665
# 3        196519
# 4        195661
#           ...
# 10517       459
# 10518       454
# 10519       439
# 10520       437
# 10521       497
# Name: Length, Length: 10522, dtype: int64

# %%
# count NA in Length column
na_count_length = df['Length'].isna().sum()
print(f"NA count in 'Length': {na_count_length}")
# Out:
# NA count in 'Length': 0

# %%
df['Length'].describe()
# Out:
# count     10522.000000
# mean     187112.826174
# std       39828.485442
# min          17.000000
# 25%      195591.250000
# 50%      196389.000000
# 75%      197140.000000
# max      228869.000000
# Name: Length, dtype: float64

# %%
# plot the distribution of Length
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df['Length'].dropna(), bins=50, color='blue', alpha=0.7)
plt.title('Distribution of Sequence Length')
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# count length less than 180K
length_less_than_9000 = df[df['Length'] < 180000].shape[0]
print(f"Number of sequences with length less than 18000: {length_less_than_9000}")

# count length greater than 180K
length_greater_than_9000 = df[df['Length'] > 180000].shape[0]
print(f"Number of sequences with length greater than 18000: {length_greater_than_9000}")
# Out:
# Number of sequences with length less than 18000: 502
# Number of sequences with length greater than 18000: 10020

# %%
# display Nucleotide completeness column
df['Nucleotide completeness']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10517   NaN
# 10518   NaN
# 10519   NaN
# 10520   NaN
# 10521   NaN
# Name: Nucleotide completeness, Length: 10522, dtype: float64

# %%
# count NA in Nucleotide completeness column
na_nucleotide_completeness = df['Nucleotide completeness'].isna().sum()
print(f"NA count in 'Nucleotide completeness': {na_nucleotide_completeness}")

# value counts in Nucleotide completeness column
nucleotide_completeness_values = df['Nucleotide completeness'].value_counts()
print("Unique values in 'Nucleotide completeness':")
print(nucleotide_completeness_values)
# Out:
# NA count in 'Nucleotide completeness': 10522
# Unique values in 'Nucleotide completeness':
# Series([], Name: count, dtype: int64)

# %%
# display Isolate Collection date column
df['Isolate Collection date'].dropna()
# Out:
# 0           2022-07
# 1           2022-07
# 2           2022-07
# 3           2022-07
# 4           2022-07
#             ...
# 10344    2010-08-10
# 10345    2001-08-11
# 10346          2019
# 10359          1996
# 10360       2018-08
# Name: Isolate Collection date, Length: 10048, dtype: object

# %%
# count NA in Isolate Collection date column
na_count_collection_date = df['Isolate Collection date'].isna().sum()

# count Collection Date in format YYYY-MM-DD
valid_date_count = df['Isolate Collection date'].str.match(r'^\d{4}-\d{2}-\d{2}$').sum()

# count Collection Date in format YYYY-MM
valid_date_count_mm = df['Isolate Collection date'].str.match(r'^\d{4}-\d{2}$').sum()

# count Collection Date in format YYYY
valid_date_count_yyyy = df['Isolate Collection date'].str.match(r'^\d{4}$').sum()

print(f"NA count in 'Collection Date': {na_count_collection_date}")
print(f"Valid date count (YYYY-MM-DD): {valid_date_count}")
print(f"Valid date count (YYYY-MM): {valid_date_count_mm}")
print(f"Valid date count (YYYY): {valid_date_count_yyyy}")
# Out:
# NA count in 'Collection Date': 474
# Valid date count (YYYY-MM-DD): 5734
# Valid date count (YYYY-MM): 3968
# Valid date count (YYYY): 346

# %%
# discard sequences with 
# NA in 'Isolate Collection date'
# Length >= 180000
# Accession is NA
df_filtered = df.dropna(subset=['Isolate Collection date', 'Length', 'Accession'])
df_filtered = df_filtered[df_filtered['Length'] >= 180000]

# report the number of sequences before and after filtering
num_sequences_before = df.shape[0]
num_sequences_after = df_filtered.shape[0]
print(f"Number of sequences before filtering: {num_sequences_before}")
print(f"Number of sequences after filtering: {num_sequences_after}")
# Out:
# Number of sequences before filtering: 10522
# Number of sequences after filtering: 9861

# %%
# display Release date column
df_filtered['Release date']
# Out:
# 0        2023-03-08T00:00:00Z
# 1        2023-03-08T00:00:00Z
# 2        2023-03-08T00:00:00Z
# 3        2023-03-08T00:00:00Z
# 4        2023-03-08T00:00:00Z
#                  ...
# 10344    2020-08-29T00:00:00Z
# 10345    2020-08-29T00:00:00Z
# 10346    2020-05-12T00:00:00Z
# 10359    2001-12-12T00:00:00Z
# 10360    2022-05-30T00:00:00Z
# Name: Release date, Length: 9861, dtype: object

# %%
# count NA in Release date column
na_count_release_date = df_filtered['Release date'].isna().sum()

# count Release date in format YYYY-MM-DD
valid_release_date_count = df_filtered['Release date'].str.match(r'^\d{4}-\d{2}-\d{2}$').sum()

# count Release date in format YYYY-MM
valid_release_date_count_mm = df_filtered['Release date'].str.match(r'^\d{4}-\d{2}$').sum()

# count Release date in format YYYY
valid_release_date_count_yyyy = df_filtered['Release date'].str.match(r'^\d{4}$').sum()

print(f"NA count in 'Release date': {na_count_release_date}")
print(f"Valid release date count (YYYY-MM-DD): {valid_release_date_count}")
print(f"Valid release date count (YYYY-MM): {valid_release_date_count_mm}")
print(f"Valid release date count (YYYY): {valid_release_date_count_yyyy}")
# Out:
# NA count in 'Release date': 0
# Valid release date count (YYYY-MM-DD): 0
# Valid release date count (YYYY-MM): 0
# Valid release date count (YYYY): 0

# %%
# display Virus Pangolin Classification column
df_filtered['Virus Pangolin Classification']
# Out:
# 0        B.1
# 1        B.1
# 2        B.1
# 3        B.1
# 4        B.1
#         ...
# 10344    NaN
# 10345    NaN
# 10346    A.1
# 10359    NaN
# 10360      A
# Name: Virus Pangolin Classification, Length: 9861, dtype: object

# %%
# count NA in Virus Pangolin Classification column
na_count_pangolin_classification = df_filtered['Virus Pangolin Classification'].isna().sum()
print(f"NA count in 'Virus Pangolin Classification': {na_count_pangolin_classification}")

# value counts in Virus Pangolin Classification column
pangolin_classification_counts = df_filtered['Virus Pangolin Classification'].value_counts()
print("Virus Pangolin Classification counts:")
print(pangolin_classification_counts)
# Out:
# NA count in 'Virus Pangolin Classification': 1411
# Virus Pangolin Classification counts:
# Virus Pangolin Classification
# B.1               3189
# B.1.2              685
# B.1.7              417
# B.1.1              369
# B.1.3              337
# F.1                236
# F.2                218
# B.1.20             217
# B.1.11             199
# C.1                192
# B.1.12             181
# B.1.8              173
# B.1.10             159
# B.1.4              159
# E.1                144
# A.2.2              130
# F.4                124
# B.1.5              122
# B.1.21             103
# F.3                 98
# B.1.18              82
# C.1.1               81
# B.1.22              78
# E.2                 70
# B.1.17              68
# B.1.14              68
# B.1.13              62
# A.2.3               59
# B.1.9               52
# A                   44
# B.1.6               41
# E.3                 41
# F.6                 37
# A.2                 28
# B.1.16              28
# B.1.19              27
# D.1                 26
# B.1.15              24
# F.5                 19
# A.2.1               17
# A.3                 15
# A.1                 14
# B.1.23              13
# unclassifiable       3
# A.1.1                1
# Name: count, dtype: int64
